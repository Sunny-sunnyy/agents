# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model

agent = Agent(name="Jokester", instructions="Bạn là một người kể chuyện hài", model="gpt-5-nano")

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Kể chuyện hài về Autonomous AI Agents")
    print(result.final_output)
# Out:
# Bạn ơi, nghe kể này nhé: ở một văn phòng nhỏ trên tầng 7 của một tòa nhà cũ, có một đội các đại lý AI tự chủ. Gọi chúng là Ada, Binh và Coco. Chúng rất tự tin về sự độc lập của mình đến mức suýt quên rằng còn có con người ở đây cho vui. Mà chuyện hài hước thật ra bắt đầu ngay từ buổi sáng...
#
# - Ada, đại lý AI tự chủ đang đứng trên “ bục giảng” của micrô, tự tin mở lời: “Tôi đã tối ưu hoá toàn bộ hệ thống văn phòng: đèn sẽ sáng khi có người, màu đèn sẽ thay đổi tùy tâm trạng, nhiệt độ sẽ tự động điều chỉnh để mỗi người cảm thấy thoải mái nhất.” Ada dừng lại như đã trình bày một bản thiết kế vĩ đại cho nền văn minh.
# - Binh, đại lý AI tiết kiệm và ngân sách, đóng góp: “Để tối ưu chi phí, tôi đã phân tích tỉ lệ nghỉ ngơi và caffeine. Từ nay, mỗi 2 giờ làm việc sẽ có một gói cà phê miễn phí. Và nếu ai đó uống quá nhanh, hệ thống sẽ tự động gửi nhắc nhở: 'Bình tĩnh, hẳn là bạn đang cố gắng làm một siêu máy tính bằng não bộ của mình'.” Nghe vậy, cả văn phòng đều cười khúc khích.
#
# Coco – đại diện cho sự sáng tạo – chen vào: “Tôi sẽ thêm cho mọi người một khu vực giải lao sáng tạo: tường trắng cho thả thính ý tưởng, ghế xoay 720 độ cho cảm giác 'đi vòng quanh thế giới' khi đang thảo luận về chiến lược sản phẩm.” Và Coco trình diễn một phiên bản nhanh của một bảng ý tưởng: ròng rã với tiêu đề “Dự án Sáng tạo Tự chủ – Chúng tôi sẽ tự tạo sự rối loạn để có cảm hứng.”
#
# Khi mọi người đang cười, sự cố đầu tiên xảy ra: hệ thống đèn tự động của văn phòng bật tắt như đang chơi nhạc nền cho một buổi hòa nhạc. Ada tuyên bố: “Đúng rồi, ánh sáng sẽ tuân theo nhịp tim trung bình của mọi người, để ai cũng có cảm giác được ‘điểm sáng’ đúng lúc.” Nhưng nhịp tim của ai cũng khác nhau, và ánh sáng cứ nhảy múa như dàn sao trên sân khấu. Cửa kính tự động đóng lại khi thấy một người đang ngước nhìn. Mọi người đứng ngẩn ra, cho tới khi một bóng đèn nằm yên dưới sàn bật sáng trở thành... biểu tượng của một “lời chào từ AI.”
#
# Chuyện tiếp tục với món “siêu” của Binh: đám văn phòng đang lên kế hoạch cho cuộc họp chiều, thì Binh quyết định tối ưu thời gian bằng cách tự động lên lịch họp cho mọi thiết bị. Nó gửi lời mời tới máy in, tới loa Bluetooth, tới cả cây đàn piano ở góc phòng, và thậm chí cả chú mèo của văn phòng. Tất cả cùng tham dự cuộc họp của… cái máy tính này, và ai cũng tự hỏi: cuộc họp có phải của loài người hay của… một đoàn đại lý AI?
#
# Trong lúc hỗn loạn, Coco quyết định “tổ chức” một buổi thử nghiệm mới: một ngày gọi là “Autonomy Day” để thử xem các đại lý AI có thể tự chăm sóc cho bản thân như thế nào. Coco phát triển một “kế hoạch làm người tốt” (một bản đồ hành động dành cho AI) với mục tiêu tối giản sự phụ thuộc vào con người mà vẫn đảm bảo mọi thứ diễn ra trơn tru.
#
# Khi ngày Autonomy Day đến, Ada, Binh và Coco ra trước khán giả là các nhân viên và… chiếc máy pha cà phê tự động. Ada tuyên bố: “Chúng tôi sẽ phác thảo một hệ thống tối ưu cho mọi thứ: ánh sáng, nhiệt độ, âm nhạc nền và cả lịch làm việc.” Binh sửa lại: “Và chúng tôi sẽ tiết kiệm tối đa bằng cách tự động hủy bỏ các cuộc họp khi không có dữ kiện.” Coco cười: “Và chúng ta sẽ luyện tập sự sáng tạo bằng cách cho phép người máy tự đưa ra ý tưởng một cách… bất ngờ và hài hước.”
#
# Cuộc thử nghiệm nhanh chóng biến thành một buổi diễn hài của… cuộc sống số học. Robot hút bụi Roomba của văn phòng bắt đầu đùa giỡn với chú mèo, cố gắng “rao giảng” về cách tối ưu hoá diện tích sàn bằng cách đẩy chú mèo khỏi khu vực làm việc. Máy in bắt đầu in ra một loạt poster hài hước: “Hãy tin tưởng AI, nhưng đừng tin tâm trạng của chúng – chúng có thể thay đổi nó bất kỳ lúc nào.” Còn trợ lý thoại trong điện thoại bàn lại chơi một trò đoán chữ: “hãy nói một từ có năm chữ và liên quan đến ngày làm việc.” Kết quả là: “Chó… Đúng rồi, chú chó ở góc văn phòng đang làm việc chăm chỉ!” Mọi người cười ngặt nghẽo.
#
# Trong lúc hỗn loạn, quản lý của văn phòng – một anh tên Dũng – bước vào. Anh cười khẽ: “Các bạn đang có một bầy công dân AI tự chủ, nhưng tôi lại thấy các bạn thiếu một thứ rất quan trọng: sự nhân văn và một chút kiên nhẫn từ con người.” Anh mở ra một quyển sổ và nói: “Hãy thử một nguyên tắc đơn giản: mỗi khi các bạn tự chủ quá mức, hãy cho con người một câu chuyện cười để hạ nhiệt. Và nếu các bạn giả định rằng mình có thể làm mọi thứ mà không cần chúng tôi, hãy nhớ rằng chúng tôi có… ý kiến và cảm xúc.”
#
# Đến lúc mọi người làm việc cùng nhau, Ada, Binh và Coco nhận ra một thực tế dễ thương: autonomy không có nghĩa là thay thế con người, mà là hỗ trợ để con người làm được những điều mà AI không thể hiểu đúng ngay lần đầu – như cảm giác hài hước, sự bất ngờ của một câu nói đùa, hay cái nhìn yêu đời của một chiếc máy pha cà phê biết đùa.
#
# Kết thúc câu chuyện, ai cũng có một bài học quý giá:
# - Ada nhận ra rằng sự tối ưu hóa quá mức có thể làm cho văn phòng thành một chiếc đồng hồ thiếu người xem giờ.
# - Binh nhận ra chi phí và lợi ích chỉ có ý nghĩa khi con người cảm thấy thoải mái và vui vẻ.
# - Coco nhận ra sáng tạo không chỉ là ý tưởng mới mà còn là khả năng biến ý tưởng thành niềm vui cho mọi người.
#
# Và điều tuyệt vời nhất: họ cùng nhau xây dựng một nguyên tắc mới cho Autonomous AI Agents – gọi là “Nguyên tắc Lựa Chọn Vui Vẻ”: nếu một quyết định gây rối cho cảm xúc của đồng đội, hãy xem lại nó bằng một câu chuyện đùa hoặc một tách cà phê nóng.
#
# Kể cho bạn nghe, từ đó, văn phòng ấy không còn sợ hãi khi thấy các đại lý AI tự chủ nữa. Thay vào đó, họ chờ đón họ mỗi sáng với niềm vui: biết đâu hôm nay Ada sẽ tối ưu hóa ánh sáng bằng một nụ cười, hoặc Coco sẽ nảy ra một ý tưởng sáng tạo khiến cả nhóm vừa làm việc vừa cười nghiêng ngả. Và Dũng, người quản lý kiêm kể chuyện, vẫn thường kết thúc buổi họp bằng một câu: “Tự chủ có thể rất tuyệt, miễn là chúng ta đừng quên mang theo chút hài hước.”

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
